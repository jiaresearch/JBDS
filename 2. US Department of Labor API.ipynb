# %% [markdown]
# ### How to query US DOL data with their API?

# %% [markdown]
# #### Find all dataset avaiable from the webpage:
# https://dataportal.dol.gov/datasets
#
# In this data catalog, you can check the 'Categories', 'Tags', and 'agencies' on the left hand side to limit the search results.
