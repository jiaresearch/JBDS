# %% [markdown]
# # Categorical Variables

# %% [markdown]
# ## Create Categorical Dtypes

# %%
import pandas as pd

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good',
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
print(df.dtypes)
# Out:
# Grades    str
# dtype: object

# %%
# Change dtype to
df1 = df["Grades"].astype("category")
print(df1.head())
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, str): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %%
# Create ordered category
my_categories=pd.CategoricalDtype(categories=['D', 'D+', 'C-', 'C', 'C+', 'B-',
                                              'B', 'B+', 'A-', 'A', 'A+'],
                                  ordered=True)
df["Grades"]=df["Grades"].astype(my_categories)
df.head()
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B

# %%
# With ordered categorical variable, we can filter it
df[df["Grades"]>"C"]
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+

# %% [markdown]
# ## Make bins

# %%
# import data, group by state, calculate mean population by state
import numpy as np

# Now we read in our dataset
df=pd.read_csv("data_intro/census.csv")

# And we reduce this to country data
df=df[df['SUMLEV']==50]

# And for a few groups
df=df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg(np.average)

df.head()
# Out:
# STNAME
# Alabama        71339.343284
# Alaska         24490.724138
# Arizona       426134.466667
# Arkansas       38878.906667
# California    642309.586207
# Name: CENSUS2010POP, dtype: float64

# %%
#  make "bins" based on range of average county population for each state
pd.cut(df,10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...
